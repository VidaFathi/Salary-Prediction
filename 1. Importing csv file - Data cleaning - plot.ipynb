# %%
import pandas as pd

# %%
df1=pd.read_csv('df.csv')

# %%
df1
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df1['Salary Estimate']
# Out:
# 0       $111K-$181K (Glassdoor est.)
# 1       $111K-$181K (Glassdoor est.)
# 2       $111K-$181K (Glassdoor est.)
# 3       $111K-$181K (Glassdoor est.)
# 4       $111K-$181K (Glassdoor est.)
#                     ...
# 5887    $42K - $76K (Glassdoor est.)
# 5888                              -1
# 5889                              -1
# 5890                              -1
# 5891              $65 - $72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
# a.removing the $signs:
# b.we will create a function for removing the $ and apply the function to the column

# %%
# a.removing the $signs:
df1['Salary Estimate'][0].replace('$',' ')
# Out:
# ' 111K- 181K (Glassdoor est.)'

# %%
# b.we will create a function for removing the $ and apply the function to the column
def dollors_remover(a):
    a = a.replace('$',' ')
    return a

# %%
df1['Salary Estimate'].apply(dollors_remover)
# Out:
# 0        111K- 181K (Glassdoor est.)
# 1        111K- 181K (Glassdoor est.)
# 2        111K- 181K (Glassdoor est.)
# 3        111K- 181K (Glassdoor est.)
# 4        111K- 181K (Glassdoor est.)
#                     ...
# 5887     42K -  76K (Glassdoor est.)
# 5888                              -1
# 5889                              -1
# 5890                              -1
# 5891               65 -  72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df1['Salary Estimate']= df1['Salary Estimate'].apply(dollors_remover)

# %%
df1
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist   111K- 181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics   111K- 181K (Glassdoor est.)
# 2                         Data Science Manager   111K- 181K (Glassdoor est.)
# 3                                 Data Analyst   111K- 181K (Glassdoor est.)
# 4                       Director, Data Science   111K- 181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer   42K -  76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer             65 -  72 Per Hour
#
# ...

# %%
# function for removing K:
def k_remover(a):
    a = a.replace('K', ' ')
    return a

# %%
df1['Salary Estimate']= df1['Salary Estimate'].apply(k_remover)

# %%
df1
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist   111 - 181  (Glassdoor est.)
# 1            Data Scientist, Product Analytics   111 - 181  (Glassdoor est.)
# 2                         Data Science Manager   111 - 181  (Glassdoor est.)
# 3                                 Data Analyst   111 - 181  (Glassdoor est.)
# 4                       Director, Data Science   111 - 181  (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer   42  -  76  (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer             65 -  72 Per Hour
#
# ...

# %%
df1=df1[df1['Salary Estimate']!='-1']

# %%
df1
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 1       111 - 181  (Glassdoor est.)     4.5
# 2       111 - 181  (Glassdoor est.)    -1.0
# 3       111 - 181  (Glassdoor est.)     3.4
# 4       111 - 181  (Glassdoor est.)     3.4
# ...

# %%
# 1.first we want to see the fields in Salary Estimate column that contains "Per Hour":
df1[df1['Salary Estimate'].str.contains('Per Hour')]
# Out:
#                                               Job Title  \
# 685             Clinical Laboratory Scientist, Per Diem
# 686                                    Sr. Data Analyst
# 687        Lead Data Science Instructor, Data Scientist
# 688   Clinical Laboratory Scientist (Per Diem, Varia...
# 689                                       Data Engineer
# 690          Clinical Laboratory Scientist - Generalist
# 691            Clinical Laboratory Scientist , Med Tech
# 1295                   Stafford Data Science Tutor Jobs
# 1296                     Spring Data Science Tutor Jobs
# 1297                 Sugar Land Data Science Tutor Jobs
# 2124                            Laboratory Scientist II
# 2125      Data Engineer - Top Secret w/ SCI Eligibility
# 2126                               Biological Scientist
# 2127                             TECHNICAL DATA ANALYST
# 2128                   Environmental Scientist/Engineer
# 2129               Data Analyst with Security Clearance
# ...

# %%
# 2.we want to remove them:
df1 = df1[~df1['Salary Estimate'].str.contains('Per Hour')]

# %%
df1
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 1       111 - 181  (Glassdoor est.)     4.5
# 2       111 - 181  (Glassdoor est.)    -1.0
# 3       111 - 181  (Glassdoor est.)     3.4
# 4       111 - 181  (Glassdoor est.)     3.4
# ...

# %%
# now we want to find the average of the salary eastimate and apply it to the whole column:
#first we use split to create a list out of the string

# %%
df1['Salary Estimate'][0].split()
# Out:
# ['111', '-', '181', '(Glassdoor', 'est.)']

# %%
df1['Salary Estimate'][0].split()[0]
# Out:
# '111'

# %%
df1['Salary Estimate'][0].split()[2]
# Out:
# '181'

# %%
def splitter(a):
    a = a.split()
    return(a)

# %%
# with "splitter" function we want to apply it to whole column of salary estimate

# %%
df1['Salary Estimate']
# Out:
# 0         111 - 181  (Glassdoor est.)
# 1         111 - 181  (Glassdoor est.)
# 2         111 - 181  (Glassdoor est.)
# 3         111 - 181  (Glassdoor est.)
# 4         111 - 181  (Glassdoor est.)
#                     ...
# 5881      38  -  64  (Glassdoor est.)
# 5882      47  -  89  (Glassdoor est.)
# 5883     66  -  113  (Glassdoor est.)
# 5886     67  -  111  (Glassdoor est.)
# 5887      42  -  76  (Glassdoor est.)
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df1['Salary Estimate'].apply(splitter)
# Out:
# 0       [111, -, 181, (Glassdoor, est.)]
# 1       [111, -, 181, (Glassdoor, est.)]
# 2       [111, -, 181, (Glassdoor, est.)]
# 3       [111, -, 181, (Glassdoor, est.)]
# 4       [111, -, 181, (Glassdoor, est.)]
#                       ...
# 5881      [38, -, 64, (Glassdoor, est.)]
# 5882      [47, -, 89, (Glassdoor, est.)]
# 5883     [66, -, 113, (Glassdoor, est.)]
# 5886     [67, -, 111, (Glassdoor, est.)]
# 5887      [42, -, 76, (Glassdoor, est.)]
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df1['Salary Estimate']=df1['Salary Estimate'].apply(splitter)
# Out:
# <ipython-input-27-e12c74f08d2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Salary Estimate']=df1['Salary Estimate'].apply(splitter)

# %%
df1
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# 2     [111, -, 181, (Glassdoor, est.)]    -1.0
# 3     [111, -, 181, (Glassdoor, est.)]     3.4
# 4     [111, -, 181, (Glassdoor, est.)]     3.4
# ...

# %%
def min_finder (a):
    a = a[0]
    return(a)

# %%
df1['Salary Estimate'].apply(min_finder)
# Out:
# 0       111
# 1       111
# 2       111
# 3       111
# 4       111
#        ...
# 5881     38
# 5882     47
# 5883     66
# 5886     67
# 5887     42
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df1['Min_Salary'] = df1['Salary Estimate'].apply(min_finder)
# Out:
# <ipython-input-31-38dfd7972852>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Min_Salary'] = df1['Salary Estimate'].apply(min_finder)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  Min_Salary         5500 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 687.6+ KB

# %%
def max_finder(a):
    a=a[2]
    return(a)

# %%
df1['Salary Estimate'].apply(max_finder)
# Out:
# 0       181
# 1       181
# 2       181
# 3       181
# 4       181
#        ...
# 5881     64
# 5882     89
# 5883    113
# 5886    111
# 5887     76
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df1['Max_Salary']= df1['Salary Estimate'].apply(max_finder)
# Out:
# <ipython-input-35-0a4047f5b37c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Max_Salary']= df1['Salary Estimate'].apply(max_finder)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  Min_Salary         5500 non-null   object
#  12  Max_Salary         5500 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 730.6+ KB

# %%
df1.head(3)
# Out:
#                            Job Title                   Salary Estimate  \
# 0              Senior Data Scientist  [111, -, 181, (Glassdoor, est.)]
# 1  Data Scientist, Product Analytics  [111, -, 181, (Glassdoor, est.)]
# 2               Data Science Manager  [111, -, 181, (Glassdoor, est.)]
#
#    Rating  Company Name      Location                    Size Founded  \
# 0     3.5   Hopper\n3.5  New York, NY   501 to 1000 employees    2007
# 1     4.5  Noom US\n4.5  New York, NY  1001 to 5000 employees    2008
# 2    -1.0      Decode_M  New York, NY       1 to 50 employees      -1
#
#    Type of ownership                   Industry             Sector  \
# 0  Company - Private            Travel Agencies   Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness  Consumer Services
# 2            Unknown                         -1                 -1
#
#                     Revenue Min_Salary Max_Salary
# 0  Unknown / Non-Applicable        111        181
# ...

# %%
# for finding an average, we have to change the format of min_salary and max salary column:

# %%
#change object to int:
df1['Min_Salary'].astype(int)
# Out:
# 0       111
# 1       111
# 2       111
# 3       111
# 4       111
#        ...
# 5881     38
# 5882     47
# 5883     66
# 5886     67
# 5887     42
# Name: Min_Salary, Length: 5500, dtype: int64

# %%
df1['Min_Salary']=df1['Min_Salary'].astype(int)
# Out:
# <ipython-input-40-b1932cdbcfba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Min_Salary']=df1['Min_Salary'].astype(int)

# %%
df1['Max_Salary']=df1['Max_Salary'].astype(int)
# Out:
# <ipython-input-41-de8b98def5d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Max_Salary']=df1['Max_Salary'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  Min_Salary         5500 non-null   int64
#  12  Max_Salary         5500 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 730.6+ KB

# %%
#create a new column called Average salary:
df1['Average_salary']= (df1['Min_Salary'] + df1['Max_Salary'])/2
# Out:
# <ipython-input-43-63a5c9cae621>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Average_salary']= (df1['Min_Salary'] + df1['Max_Salary'])/2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  Min_Salary         5500 non-null   int64
#  12  Max_Salary         5500 non-null   int64
#  13  Average_salary     5500 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 773.6+ KB

# %%
#now we want to clear location column:
df1['Location'].value_counts()
# Out:
# Austin, TX         345
# Chicago, IL        333
# San Diego, CA      327
# New York, NY       303
# Los Angeles, CA    229
#                   ...
# Maywood, IL          1
# Somerville, MA       1
# Pensacola, FL        1
# Danvers, MA          1
# Pennsauken, NJ       1
# Name: Location, Length: 501, dtype: int64

# %%
df1['Location'][0]
# Out:
# 'New York, NY'

# %%
# convert the column to a list:
df1['Location'][0].split()
# Out:
# ['New', 'York,', 'NY']

# %%
df1['Location'][0].split()[-1]
# Out:
# 'NY'

# %%
def state(a):
    a = a.split()
    a = a[-1]
    return a

# %%
df1['State']=df1['Location'].apply(state)
# Out:
# <ipython-input-50-cec8ea158f20>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State']=df1['Location'].apply(state)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  Min_Salary         5500 non-null   int64
#  12  Max_Salary         5500 non-null   int64
#  13  Average_salary     5500 non-null   float64
#  14  State              5500 non-null   object
# dtypes: float64(2), int64(2), object(11)
# ...

# %%
df1['State'].value_counts()
# Out:
# CA         1311
# TX         1243
# OH          408
# IL          368
# PA          324
# NY          313
# AZ          297
# FL          261
# MA          239
# NJ          232
# MI          203
# VA          131
# DC           85
# MD           61
# DE           10
# Kingdom       4
# WI            3
# NM            1
# IN            1
# ME            1
# NC            1
# NH            1
# GA            1
# KY            1
# Name: State, dtype: int64

# %%
# we want to filter the dataframe(remove Kingdom from nstate column):
df1[df1['State']!= 'Kingdom']
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# 2     [111, -, 181, (Glassdoor, est.)]    -1.0
# 3     [111, -, 181, (Glassdoor, est.)]     3.4
# 4     [111, -, 181, (Glassdoor, est.)]     3.4
# ...

# %%
df1 = df1[df1['State']!= 'Kingdom']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5496 entries, 0 to 5887
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5496 non-null   object
#  1   Salary Estimate    5496 non-null   object
#  2   Rating             5496 non-null   float64
#  3   Company Name       5496 non-null   object
#  4   Location           5496 non-null   object
#  5   Size               5496 non-null   object
#  6   Founded            5496 non-null   object
#  7   Type of ownership  5496 non-null   object
#  8   Industry           5496 non-null   object
#  9   Sector             5496 non-null   object
#  10  Revenue            5496 non-null   object
#  11  Min_Salary         5496 non-null   int64
#  12  Max_Salary         5496 non-null   int64
#  13  Average_salary     5496 non-null   float64
#  14  State              5496 non-null   object
# dtypes: float64(2), int64(2), object(11)
# ...

# %%
# we want to filter dataframe based on Rating column:
df1[df1['Rating']!= -1]
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 3                                          Data Analyst
# 4                                Director, Data Science
# 5                                        Data Scientist
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# 3     [111, -, 181, (Glassdoor, est.)]     3.4
# 4     [111, -, 181, (Glassdoor, est.)]     3.4
# 5     [111, -, 181, (Glassdoor, est.)]     2.9
# ...

# %%
df1 = df1[df1['Rating']!= -1]

# %%
# job title columnn:
df1['Job Title'].value_counts()
# Out:
# Data Scientist                                                    530
# Data Analyst                                                      296
# Data Engineer                                                     267
# Senior Data Scientist                                             117
# Machine Learning Engineer                                          55
#                                                                  ...
# Senior HR Data Analyst                                              1
# Data Scientist/Lead Data Scientist                                  1
# Data Scientist, FEAR                                                1
# Scientist, GPCR Molecular and Cellular Pharmacology - La Jolla      1
# Data Engineer-Sr Specialist                                         1
# Name: Job Title, Length: 2552, dtype: int64

# %%
#we want to categorized job titles by if clause:

# %%
def title_organizer(a):
    a = a.lower()
    if('data scientist' in a ) or ('data science' in a):
        return 'data scientist'
    elif 'data engineer' in a:
        return 'data engineer'
    elif 'deep learning' in a:
        return 'deep learning engineer'
    elif 'machine learning' in a:
        return 'machine learning engineer'
    elif 'director' in a:
        return 'director'
    elif 'analyst' in a:
        return 'analyst'
    elif 'researcher' in a:
        return 'researcher'
    else:
        return 'other'

# %%
df1['Job Title'].apply(title_organizer)
# Out:
# 0       data scientist
# 1       data scientist
# 3              analyst
# 4       data scientist
# 5       data scientist
#              ...
# 5881             other
# 5882             other
# 5883             other
# 5886           analyst
# 5887           analyst
# Name: Job Title, Length: 4891, dtype: object

# %%
df1['Job Title'] = df1['Job Title'].apply(title_organizer)

# %%
df1
# Out:
#            Job Title                   Salary Estimate  Rating  \
# 0     data scientist  [111, -, 181, (Glassdoor, est.)]     3.5
# 1     data scientist  [111, -, 181, (Glassdoor, est.)]     4.5
# 3            analyst  [111, -, 181, (Glassdoor, est.)]     3.4
# 4     data scientist  [111, -, 181, (Glassdoor, est.)]     3.4
# 5     data scientist  [111, -, 181, (Glassdoor, est.)]     2.9
# ...              ...                               ...     ...
# 5881           other    [38, -, 64, (Glassdoor, est.)]     3.2
# 5882           other    [47, -, 89, (Glassdoor, est.)]     4.2
# 5883           other   [66, -, 113, (Glassdoor, est.)]     4.0
# 5886         analyst   [67, -, 111, (Glassdoor, est.)]     4.0
# 5887         analyst    [42, -, 76, (Glassdoor, est.)]     3.6
#
#                                          Company Name        Location  \
# 0                                         Hopper\n3.5    New York, NY
# ...

# %%
df1['Job Title'].value_counts()
# Out:
# data scientist               1793
# other                        1073
# analyst                      1051
# data engineer                 764
# machine learning engineer     162
# researcher                     30
# director                       15
# deep learning engineer          3
# Name: Job Title, dtype: int64

# %%
# now we drop the extra columns:
df1.drop(columns='Salary Estimate', inplace=True)

# %%
df1
# Out:
#            Job Title  Rating                                     Company Name  \
# 0     data scientist     3.5                                      Hopper\n3.5
# 1     data scientist     4.5                                     Noom US\n4.5
# 3            analyst     3.4                            Sapphire Digital\n3.4
# 4     data scientist     3.4                  United Entertainment Group\n3.4
# 5     data scientist     2.9                               IFG Companies\n2.9
# ...              ...     ...                                              ...
# 5881           other     3.2                                         CAS\n3.2
# 5882           other     4.2  Centers for Disease Control and Prevention\n4.2
# 5883           other     4.0                                     Certara\n4.0
# 5886         analyst     4.0                                   New Relic\n4.0
# 5887         analyst     3.6                                 Hose Master\n3.6
#
# ...

# %%
df1 = df1.drop(columns = ['Company Name','Location','Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Min_Salary' , 'Max_Salary'])

# %%
df1
# Out:
#            Job Title  Rating  Average_salary State
# 0     data scientist     3.5           146.0    NY
# 1     data scientist     4.5           146.0    NY
# 3            analyst     3.4           146.0    NJ
# 4     data scientist     3.4           146.0    NY
# 5     data scientist     2.9           146.0    NY
# ...              ...     ...             ...   ...
# 5881           other     3.2            51.0    OH
# 5882           other     4.2            68.0    OH
# 5883           other     4.0            89.5    OH
# 5886         analyst     4.0            89.0    OH
# 5887         analyst     3.6            59.0    OH
#
# [4891 rows x 4 columns]

# %%
# we want to plot the histogram of the continous salary:
# either can use 'Pandas' library or 'matplotlib' or 'seaborn':

# %%
# Histrogram plot with 'Pandas':
df1['Average_salary'].hist(bins=5, color='blue')
# Out:
# <Axes: >

# %%
df1['Average_salary'].hist(bins=10, color='red')
# Out:
# <Axes: >

# %%
# Histrogram plot with 'seaborn':
import seaborn as sns

# %%
sns.displot(x='Rating' , data=df1 , bins=10)

# %%
sns.countplot(x='Job Title', data=df1)
# Out:
# <Axes: xlabel='Job Title', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Job Title', data=df1)
# asamiye nemodare x ro 45 darage taghir mide ke betonim title ro bebinim
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'data scientist'),
#   Text(1, 0, 'analyst'),
#   Text(2, 0, 'researcher'),
#   Text(3, 0, 'other'),
#   Text(4, 0, 'data engineer'),
#   Text(5, 0, 'machine learning engineer'),
#   Text(6, 0, 'director'),
#   Text(7, 0, 'deep learning engineer')])

# %%
sns.boxplot(x='Rating', data=df1)
# Out:
# <Axes: xlabel='Rating'>
